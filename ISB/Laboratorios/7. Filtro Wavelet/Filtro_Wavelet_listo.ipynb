# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import firwin, lfilter
from tqdm import tqdm
from scipy import signal
import pywt

# %% [markdown]
# # Para el ECG

# %% [markdown]
# ECG en reposo:

# %%
# leyendo archivo texto
archivo_txt = "/content/NormalBreath30s.txt"
datos_ecg = np.loadtxt(archivo_txt)
senal = datos_ecg[:, 5]  # Sexta columna

# arreglo para los tiempos
frecuencia_muestreo = 1000 #Hz
tiempo = np.arange(0,np.size(senal))/frecuencia_muestreo

#Asimismo, la funcion de tranferencia
senal=(((senal/1024)-0.5)*3.3)/(1100)
senal=senal*frecuencia_muestreo;

# Aplicar la transformada wavelet
coeffs = pywt.wavedec(senal, 'db6', level=6)

# Visualizar todos los niveles de la wavelet
plt.figure(figsize=(8, 12))
for i, coeff in enumerate(coeffs):
    plt.subplot(len(coeffs) + 1, 1, i + 1)
    plt.plot(coeff,'m')
    plt.ylabel(f'Coeff (N={i})')

plt.subplots_adjust(hspace=0.5)

# Filtrar los coeficientes
sigma = np.median(np.abs(coeffs[-1])) / 0.6745  # Estimación robusta del ruido

# Calcular el umbral universal
N = len(senal)
threshold = sigma * np.sqrt(2 * np.log(N))
filtered_coeffs = [pywt.threshold(c, threshold, mode='soft') for c in coeffs]

# Reconstruir la señal filtrada
filtered_signal = pywt.waverec(filtered_coeffs, 'db6')

plt.suptitle('Niveles (N) del 0-8 respectivamente', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.97])

plt.show()

plt.figure(figsize=(8, 12))
plt.subplot(2, 1, 1)
plt.plot(tiempo[20000:24000], senal[20000:24000],'m')
plt.title('Señal original ECG Reposo')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')

plt.subplot(2, 1, 2)
plt.plot(tiempo[20000:24000], filtered_signal[20000:24000],'m')
plt.title('Señal filtrada ECG Reposo')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
# Out:
# Text(0, 0.5, 'Amplitud')

# %% [markdown]
# EEG Inhalando/Aguantando/Exhalando por 5s

# %%
# leyendo archivo texto
archivo_txt = "/content/InHoldEx5s.txt"
datos_ecg = np.loadtxt(archivo_txt)
senal = datos_ecg[:, 5]  # Sexta columna

# arreglo para los tiempos
frecuencia_muestreo = 1000 #Hz
tiempo = np.arange(0,np.size(senal))/frecuencia_muestreo

#Asimismo, la funcion de tranferencia
senal=(((senal/1024)-0.5)*3.3)/(1100)
senal=senal*frecuencia_muestreo;

# Aplicar la transformada wavelet
coeffs = pywt.wavedec(senal, 'db6', level=6)

# Visualizar todos los niveles de la wavelet
plt.figure(figsize=(8, 12))
for i, coeff in enumerate(coeffs):
    plt.subplot(len(coeffs) + 1, 1, i + 1)
    plt.plot(coeff,'m')
    plt.ylabel(f'Coeff (N={i})')

plt.subplots_adjust(hspace=0.5)

# Filtrar los coeficientes
sigma = np.median(np.abs(coeffs[-1])) / 0.6745  # Estimación robusta del ruido

# Calcular el umbral universal
N = len(senal)
threshold = sigma * np.sqrt(2 * np.log(N))
filtered_coeffs = [pywt.threshold(c, threshold, mode='soft') for c in coeffs]

# Reconstruir la señal filtrada
filtered_signal = pywt.waverec(filtered_coeffs, 'db6')

plt.suptitle('Niveles (N) del 0-8 respectivamente', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.97])

plt.show()

plt.figure(figsize=(8, 12))
plt.subplot(2, 1, 1)
plt.plot(tiempo[20000:24000], senal[20000:24000],'m')
plt.title('Señal original ECG Inhalando/Aguantando/Exhalando por 5s')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')

plt.subplot(2, 1, 2)
plt.plot(tiempo[20000:24000], filtered_signal[20000:24000],'m')
plt.title('Señal filtrada ECG Inhalando/Aguantando/Exhalando por 5s')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
# Out:
# Text(0, 0.5, 'Amplitud')

# %% [markdown]
# EEG post burpee:

# %%
# leyendo archivo texto
archivo_txt = "/content/ReposandoBurpee30s.txt"
datos_ecg = np.loadtxt(archivo_txt)
senal = datos_ecg[:, 5]  # Sexta columna

# arreglo para los tiempos
frecuencia_muestreo = 1000 #Hz
tiempo = np.arange(0,np.size(senal))/frecuencia_muestreo

#Asimismo, la funcion de tranferencia
senal=(((senal/1024)-0.5)*3.3)/(1100)
senal=senal*frecuencia_muestreo;

# Aplicar la transformada wavelet
coeffs = pywt.wavedec(senal, 'db6', level=6)

# Visualizar todos los niveles de la wavelet
plt.figure(figsize=(8, 12))
for i, coeff in enumerate(coeffs):
    plt.subplot(len(coeffs) + 1, 1, i + 1)
    plt.plot(coeff,'m')
    plt.ylabel(f'Coeff (N={i})')

plt.subplots_adjust(hspace=0.5)

# Filtrar los coeficientes
sigma = np.median(np.abs(coeffs[-1])) / 0.6745  # Estimación robusta del ruido

# Calcular el umbral universal
N = len(senal)
threshold = sigma * np.sqrt(2 * np.log(N))
filtered_coeffs = [pywt.threshold(c, threshold, mode='soft') for c in coeffs]

# Reconstruir la señal filtrada
filtered_signal = pywt.waverec(filtered_coeffs, 'db6')

plt.suptitle('Niveles (N) del 0-8 respectivamente', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.97])

plt.show()

plt.figure(figsize=(8, 12))
plt.subplot(2, 1, 1)
plt.plot(tiempo[20000:24000], senal[20000:24000],'m')
plt.title('Señal original ECG Post Burpee')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')

plt.subplot(2, 1, 2)
plt.plot(tiempo[20000:24000], filtered_signal[20000:24000],'m')
plt.title('Señal filtrada ECG Post Burpee')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
# Out:
# Text(0, 0.5, 'Amplitud')

# %% [markdown]
# # PARA EEG

# %% [markdown]
# EEG en reposo:

# %%
# leyendo archivo texto
archivo_txt = "/content/EEG_PrimeroOsjoscerrados.txt"
datos_eeg = np.loadtxt(archivo_txt)
senal = datos_eeg[:, 5]  # Sexta columna

# arreglo para los tiempos
frecuencia_muestreo = 1000 #Hz
tiempo = np.arange(np.size(senal))/frecuencia_muestreo

#Asimismo, la funcion de tranferencia
senal=(((senal/1024)-0.5)*3.3)/(41782)
senal=senal*3000000 #Tomando 30s de toma de datos
senal=senal[0:30000]
tiempo=tiempo[0:30000]

# Aplicar la transformada wavelet
coeffs = pywt.wavedec(senal, 'db8', level=8)

# Visualizar todos los niveles de la wavelet
plt.figure(figsize=(8,12))
for i, coeff in enumerate(coeffs):
    plt.subplot(len(coeffs) + 1, 1, i + 1)
    plt.plot(coeff,'b')
    plt.ylabel(f'Coeff (N={i})')

plt.subplots_adjust(hspace=0.5)

# Filtrar los coeficientes eliminando los detalles no deseados
coeffs[1] *= 0
coeffs[2] *= 0
coeffs[8] *= 0

# Reconstruir la señal filtrada
filtered_signal = pywt.waverec(coeffs, 'db8')

plt.suptitle('Niveles (N) de la señal EEG en reposo', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.97])

plt.show()

plt.figure(figsize=(8,12))
plt.subplot(2, 1, 1)
plt.plot(tiempo[20000:22000], senal[20000:22000],'b')
plt.title('Señal EEG reposo original')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')

plt.subplot(2, 1, 2)
plt.plot(tiempo[20000:22000], filtered_signal[20000:22000],'b')
plt.title('Señal EEG reposo filtrada')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
# Out:
# Text(0, 0.5, 'Amplitud')

# %% [markdown]
# EEG ABRIENDO/CERRANDO OJOS

# %%
# leyendo archivo texto
archivo_txt = "/content/EEG_2_5s.txt"
datos_eeg = np.loadtxt(archivo_txt)
senal = datos_eeg[:, 5]  # Sexta columna

# arreglo para los tiempos
frecuencia_muestreo = 1000 #Hz
tiempo = np.arange(np.size(senal))/frecuencia_muestreo

#Asimismo, la funcion de tranferencia
senal=(((senal/1024)-0.5)*3.3)/(41782)
senal=senal*3000000 #Tomando 30s de toma de datos
senal=senal[0:30000]
tiempo=tiempo[0:30000]

# Aplicar la transformada wavelet
coeffs = pywt.wavedec(senal, 'db8', level=8)

# Visualizar todos los niveles de la wavelet
plt.figure(figsize=(8,12))
for i, coeff in enumerate(coeffs):
    plt.subplot(len(coeffs) + 1, 1, i + 1)
    plt.plot(coeff,'b')
    plt.ylabel(f'Coeff (N={i})')

plt.subplots_adjust(hspace=0.5)

# Filtrar los coeficientes eliminando los detalles no deseados
coeffs[1] *= 0
coeffs[2] *= 0
coeffs[8] *= 0

# Reconstruir la señal filtrada
filtered_signal = pywt.waverec(coeffs, 'db8')

plt.suptitle('Niveles (N) de la señal EEG abriendo/cerrando ojos', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.97])

plt.show()

plt.figure(figsize=(8,12))
plt.subplot(2, 1, 1)
plt.plot(tiempo[9000:11000], senal[9000:11000],'b')
plt.title('Señal EEG original abriendo/cerrando ojos')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')

plt.subplot(2, 1, 2)
plt.plot(tiempo[9000:11000], filtered_signal[9000:11000],'b')
plt.title('Señal EEG filtrada abriendo/cerrando ojos')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
# Out:
# Text(0, 0.5, 'Amplitud')

# %% [markdown]
# EEG resolviendo ejercicios de mate

# %%
# leyendo archivo texto
archivo_txt = "/content/ejmate.txt"
datos_eeg = np.loadtxt(archivo_txt)
senal = datos_eeg[:, 5]  # Sexta columna

# arreglo para los tiempos
frecuencia_muestreo = 1000 #Hz
tiempo = np.arange(np.size(senal))/frecuencia_muestreo

#Asimismo, la funcion de tranferencia
senal=(((senal/1024)-0.5)*3.3)/(41782)
senal=senal*3000000 #Tomando 30s de toma de datos
senal=senal[0:30000]
tiempo=tiempo[0:30000]

# Aplicar la transformada wavelet
coeffs = pywt.wavedec(senal, 'db8', level=8)

# Visualizar todos los niveles de la wavelet
plt.figure(figsize=(8,12))
for i, coeff in enumerate(coeffs):
    plt.subplot(len(coeffs) + 1, 1, i + 1)
    plt.plot(coeff,'b')
    plt.ylabel(f'Coeff (N={i})')

plt.subplots_adjust(hspace=0.5)

# Filtrar los coeficientes eliminando los detalles no deseados
coeffs[1] *= 0
coeffs[2] *= 0
coeffs[8] *= 0

# Reconstruir la señal filtrada
filtered_signal = pywt.waverec(coeffs, 'db8')

plt.suptitle('Niveles (N) de la señal EEG resolviendo ejercicios de mate', fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.97])

plt.show()

plt.figure(figsize=(8,12))
plt.subplot(2, 1, 1)
plt.plot(tiempo[13000:15000], senal[13000:15000],'b')
plt.title('Señal EEG original resolviendo ejercicios de mate')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')

plt.subplot(2, 1, 2)
plt.plot(tiempo[13000:15000], filtered_signal[13000:15000],'b')
plt.title('Señal EEG filtrada resolviendo ejercicios de mate')
plt.xlabel('Tiempo')
plt.ylabel('Amplitud')
# Out:
# Text(0, 0.5, 'Amplitud')

# %% [markdown]
# # PARA EMG:

# %% [markdown]
# EMG en reposo:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pywt

# Cargar la señal EMG
arrayemg = np.genfromtxt("text_EMG.txt", delimiter="\t", skip_header=3, missing_values=0)
Fs = 1000  # Frecuencia de muestreo en Hz

# Seleccionar los primeros 10 segundos de la señal
duration = 10 # Duración en segundos
samples = Fs * duration # Número de muestras correspondientes a los primeros 10 segundos
signalemg = arrayemg[:samples, 5]
n = len(signalemg)
t = np.arange(0, n / Fs, 1 / Fs)

# Análisis de Wavelets
wavelet = 'db4'
levels = 5
coeffs = pywt.wavedec(signalemg, wavelet, level=levels)

# Visualización
plt.figure(figsize=(15, 20))

# Señal EMG Original
plt.subplot(5, 1, 1)
plt.plot(t, signalemg, label='Original EMG')
plt.title('Señal EMG Original')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.legend()

# Coeficientes de Wavelet Detalle (Niveles 1-4)
for i in range(1, 5):
    plt.subplot(5, 1, i + 1)
    plt.plot(coeffs[i], label=f'Detalle Nivel {i}')
    plt.title(f'Coeficientes de Detalle Nivel {i}')
    plt.xlabel('Muestras')
    plt.ylabel('Amplitud')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# EMG contracción leve

# %%
import numpy as np
import matplotlib.pyplot as plt
import pywt

# Cargar la señal EMG
arrayemg = np.genfromtxt("text_EMG.txt", delimiter="\t", skip_header=3, missing_values=0)
Fs = 1000  # Frecuencia de muestreo en Hz

# Definir el intervalo de tiempo que deseas visualizar (segundos)
inicio_segundo = 13.5
fin_segundo = 15
inicio_muestra = int(inicio_segundo * Fs)
fin_muestra = int(fin_segundo * Fs)

# Seleccionar los datos en el intervalo deseado
signalemg = arrayemg[inicio_muestra:fin_muestra, 5]
n = len(signalemg)
t = np.arange(inicio_segundo, fin_segundo, 1 / Fs)

# Análisis de Wavelets
wavelet = 'db4'
levels = 5
coeffs = pywt.wavedec(signalemg, wavelet, level=levels)

# Visualización
plt.figure(figsize=(15, 20))

# Señal EMG Original
plt.subplot(5, 1, 1)
plt.plot(t, signalemg, label='Original EMG')
plt.title('Señal EMG Original (13.5-15s)')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.grid(True)
plt.legend()

# Coeficientes de Wavelet Detalle (Niveles 1-4)
for i in range(1, 5):
    plt.subplot(5, 1, i + 1)
    plt.plot(coeffs[i], label=f'Detalle Nivel {i}')
    plt.title(f'Coeficientes de Detalle Nivel {i}')
    plt.xlabel('Muestras')
    plt.ylabel('Amplitud')
    plt.grid(True)
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# EMG contracción fuerte

# %%
import numpy as np
import matplotlib.pyplot as plt
import pywt

# Cargar la señal EMG
arrayemg = np.genfromtxt("text_EMG.txt", delimiter="\t", skip_header=3, missing_values=0)
Fs = 1000  # Frecuencia de muestreo en Hz

# Definir el intervalo de tiempo que deseas visualizar (segundos)
inicio_segundo = 15
fin_segundo = 18
inicio_muestra = int(inicio_segundo * Fs)
fin_muestra = int(fin_segundo * Fs)

# Seleccionar los datos en el intervalo deseado
signalemg = arrayemg[inicio_muestra:fin_muestra, 5]
n = len(signalemg)
t = np.arange(inicio_segundo, fin_segundo, 1 / Fs)

# Análisis de Wavelets
wavelet = 'db4'
levels = 5
coeffs = pywt.wavedec(signalemg, wavelet, level=levels)

# Visualización
plt.figure(figsize=(15, 20))

# Señal EMG Original
plt.subplot(5, 1, 1)
plt.plot(t, signalemg, label='Original EMG')
plt.title('Señal EMG Original (13.5-15s)')
plt.xlabel('Tiempo (s)')
plt.ylabel('Amplitud')
plt.grid(True)
plt.legend()

# Coeficientes de Wavelet Detalle (Niveles 1-4)
for i in range(1, 5):
    plt.subplot(5, 1, i + 1)
    plt.plot(coeffs[i], label=f'Detalle Nivel {i}')
    plt.title(f'Coeficientes de Detalle Nivel {i}')
    plt.xlabel('Muestras')
    plt.ylabel('Amplitud')
    plt.grid(True)
    plt.legend()

plt.tight_layout()
plt.show()
